# %% [markdown]
# **CvC-cleanicDB and Kavasir-seg**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Data pre-processing
meta_data = pd.read_csv("main_metadata.csv")
meta_data
# Out:
#       Unnamed: 0                                     image_path  \
# 0              0               Polyp_dataset/PNG/Original/1.png
# 1              1              Polyp_dataset/PNG/Original/10.png
# 2              2             Polyp_dataset/PNG/Original/100.png
# 3              3             Polyp_dataset/PNG/Original/101.png
# 4              4             Polyp_dataset/PNG/Original/102.png
# ...          ...                                            ...
# 1608        1608  seg-data/images/cju7dff9529h208503w60lbil.jpg
# 1609        1609  seg-data/images/cju2p0eveqtdc0835gpi3p93i.jpg
# 1610        1610  seg-data/images/cju1hhj6mxfp90835n3wofrap.jpg
# 1611        1611  seg-data/images/cju2yi9tz8vky0801yqip0xyl.jpg
# 1612        1612  seg-data/images/cju2np2k9zi3v079992ypxqkn.jpg
#
#                                          mask_path
# 0             Polyp_dataset/PNG/Ground Truth/1.png
# 1            Polyp_dataset/PNG/Ground Truth/10.png
# ...

# %%
def load_data(meta_data, target_size = (256,256)):
    image_dir = np.array(meta_data["image_path"])
    mask_dir = np.array(meta_data["mask_path"])
#Arrays for images and masks
    images, masks = [],[]
    
    for img, mask in zip(image_dir,mask_dir):
        #Reading images and masks
        image = cv2.imread(img)
        if image.shape[-1] == 4:
            image = cv2.cvtColor(image, cv2.COLOR_BGRA2BGR)
        mask = cv2.imread(mask, cv2.IMREAD_GRAYSCALE)

        #Resizing image and masks
        image = cv2.resize(image, target_size)
        mask = cv2.resize(mask, target_size)

        #Normalizing image 
        image = image/255.0
        mask = mask/255.0
        mask = np.expand_dims(mask, axis = -1)

        images.append(image)
        masks.append(mask)
    return np.array(images), np.array(masks)

# %%
X,Y = load_data(meta_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 X,Y = load_data(meta_data)
#
# Cell In[37], line 10, in load_data(meta_data, target_size)
#       7 for img, mask in zip(image_dir,mask_dir):
#       8     #Reading images and masks
#       9     image = cv2.imread(img)
# ---> 10     if image.shape[-1] == 4:
#      11         image = cv2.cvtColor(image, cv2.COLOR_BGRA2BGR)
#      12     mask = cv2.imread(mask, cv2.IMREAD_GRAYSCALE)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
image_dir = np.array(meta_data["image_path"])
img = cv2.imread(image_dir[3])
img
# Out:
# array([[[21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        [[21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        [[21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        ...,
#
#        [[22, 22, 22],
#         [22, 22, 22],
#         [22, 22, 22],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        [[21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        [[20, 20, 20],
#         [20, 20, 20],
#         [20, 20, 20],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]]], dtype=uint8)
